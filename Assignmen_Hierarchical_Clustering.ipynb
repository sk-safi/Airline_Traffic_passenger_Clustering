# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv(r"C:\Users\hp\Desktop\My_Project\Airtraffic_Passenger_statistic\AirTraffic_Passenger_Statistics.csv")
df.head()
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code GEO Region  \
# 0           200507      ATA Airlines                          TZ         US
# 1           200507      ATA Airlines                          TZ         US
# 2           200507      ATA Airlines                          TZ         US
# 3           200507       Air Canada                           AC     Canada
# 4           200507       Air Canada                           AC     Canada
#
#      Terminal Boarding Area  Passenger Count  Year Month
# 0  Terminal 1             B            27271  2005  July
# 1  Terminal 1             B            29131  2005  July
# 2  Terminal 1             B             5415  2005  July
# 3  Terminal 1             B            35156  2005  July
# 4  Terminal 1             B            34090  2005  July

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15007 entries, 0 to 15006
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              15007 non-null  int64
#  1   Operating Airline            15007 non-null  object
#  2   Operating Airline IATA Code  14953 non-null  object
#  3   GEO Region                   15007 non-null  object
#  4   Terminal                     15007 non-null  object
#  5   Boarding Area                15007 non-null  object
#  6   Passenger Count              15007 non-null  int64
#  7   Year                         15007 non-null  int64
#  8   Month                        15007 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        Activity Period  Passenger Count          Year
# count     15007.000000     15007.000000  15007.000000
# mean     201045.073366     29240.521090   2010.385220
# std         313.336196     58319.509284      3.137589
# min      200507.000000         1.000000   2005.000000
# 25%      200803.000000      5373.500000   2008.000000
# 50%      201011.000000      9210.000000   2010.000000
# 75%      201308.000000     21158.500000   2013.000000
# max      201603.000000    659837.000000   2016.000000

# %%
df.rename(columns = {'Activity Period':'Activity_Period', 'Operating Airline':'Operating_Airline',"Operating Airline IATA Code":"Operating_Cod",
                     "GEO Region":"GEO_Region","Price Category Code":"Price_Category_Code","Boarding Area":"Boarding_Area","Passenger Count":"Passenger_Count"
                    }, inplace = True)
df.head()
# Out:
#    Activity_Period Operating_Airline Operating_Cod GEO_Region    Terminal  \
# 0           200507      ATA Airlines            TZ         US  Terminal 1
# 1           200507      ATA Airlines            TZ         US  Terminal 1
# 2           200507      ATA Airlines            TZ         US  Terminal 1
# 3           200507       Air Canada             AC     Canada  Terminal 1
# 4           200507       Air Canada             AC     Canada  Terminal 1
#
#   Boarding_Area  Passenger_Count  Year Month
# 0             B            27271  2005  July
# 1             B            29131  2005  July
# 2             B             5415  2005  July
# 3             B            35156  2005  July
# 4             B            34090  2005  July

# %%
df.isnull().sum()
# Out:
# Activity_Period       0
# Operating_Airline     0
# Operating_Cod        54
# GEO_Region            0
# Terminal              0
# Boarding_Area         0
# Passenger_Count       0
# Year                  0
# Month                 0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#        Activity_Period Operating_Airline Operating_Cod GEO_Region  \
# 0               200507      ATA Airlines            TZ         US
# 1               200507      ATA Airlines            TZ         US
# 2               200507      ATA Airlines            TZ         US
# 3               200507       Air Canada             AC     Canada
# 4               200507       Air Canada             AC     Canada
# ...                ...               ...           ...        ...
# 15002           201603    Virgin America            VX         US
# 15003           201603    Virgin America            VX     Mexico
# 15004           201603    Virgin America            VX     Mexico
# 15005           201603   Virgin Atlantic            VS     Europe
# 15006           201603   Virgin Atlantic            VS     Europe
#
#             Terminal Boarding_Area  Passenger_Count  Year  Month
# 0         Terminal 1             B            27271  2005   July
# ...

# %%
df.dropna()
# Out:
#        Activity_Period Operating_Airline Operating_Cod GEO_Region  \
# 0               200507      ATA Airlines            TZ         US
# 1               200507      ATA Airlines            TZ         US
# 2               200507      ATA Airlines            TZ         US
# 3               200507       Air Canada             AC     Canada
# 4               200507       Air Canada             AC     Canada
# ...                ...               ...           ...        ...
# 15002           201603    Virgin America            VX         US
# 15003           201603    Virgin America            VX     Mexico
# 15004           201603    Virgin America            VX     Mexico
# 15005           201603   Virgin Atlantic            VS     Europe
# 15006           201603   Virgin Atlantic            VS     Europe
#
#             Terminal Boarding_Area  Passenger_Count  Year  Month
# 0         Terminal 1             B            27271  2005   July
# ...

# %%
df.shape
# Out:
# (15007, 9)

# %%
plt.figure(figsize = (40,8))
df.plot(kind = 'box', subplots = True)
# Out:
# Activity_Period       Axes(0.125,0.11;0.227941x0.77)
# Passenger_Count    Axes(0.398529,0.11;0.227941x0.77)
# Year               Axes(0.672059,0.11;0.227941x0.77)
# dtype: object

# %%
plt.figure(figsize = (10,20))
sns.boxplot(df['Passenger_Count'])
# Out:
# <Axes: ylabel='Passenger_Count'>

# %%
Q1 = df['Passenger_Count'].quantile(0.25)
Q2 = df['Passenger_Count'].quantile(0.75)

IQR = Q2-Q1
IQR
# Out:
# 15785.0

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q2 + 1.5 * IQR
cleaned_df = df[df['Passenger_Count'] <= 20000]

# %%
plt.figure(figsize = (10,5))
sns.boxplot(cleaned_df['Passenger_Count'])
# Out:
# <Axes: ylabel='Passenger_Count'>

# %%
plt.figure(figsize = (60,8))
cleaned_df.plot(kind = 'box', subplots = True)
# Out:
# Activity_Period       Axes(0.125,0.11;0.227941x0.77)
# Passenger_Count    Axes(0.398529,0.11;0.227941x0.77)
# Year               Axes(0.672059,0.11;0.227941x0.77)
# dtype: object

# %%
cleaned_df.shape
# Out:
# (11057, 9)

# %%
cleaned_df.tail()
# Out:
#        Activity_Period Operating_Airline Operating_Cod GEO_Region  \
# 15000           201603   United Airlines            UA     Mexico
# 15003           201603    Virgin America            VX     Mexico
# 15004           201603    Virgin America            VX     Mexico
# 15005           201603   Virgin Atlantic            VS     Europe
# 15006           201603   Virgin Atlantic            VS     Europe
#
#             Terminal Boarding_Area  Passenger_Count  Year  Month
# 15000     Terminal 3             F            17521  2016  March
# 15003  International             A             4189  2016  March
# 15004     Terminal 2             D             4693  2016  March
# 15005  International             A            12313  2016  March
# 15006  International             A            10898  2016  March

# %%
import missingno as msno
msno.bar(cleaned_df, figsize = (16,5),color = "black")
plt.show()

# %%
cleaned_df.GEO_Region.value_counts()
# Out:
# GEO_Region
# Asia                   2947
# US                     2706
# Europe                 1747
# Canada                 1281
# Mexico                 1061
# Australia / Oceania     737
# Central America         274
# Middle East             214
# South America            90
# Name: count, dtype: int64

# %%
plt.figure(figsize = (16,8))
sns.countplot(data=cleaned_df,x="Boarding_Area",palette="Pastel1")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24704\2196659313.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=cleaned_df,x="Boarding_Area",palette="Pastel1")

# %%
cleaned_df.columns
# Out:
# Index(['Activity_Period', 'Operating_Airline', 'Operating_Cod', 'GEO_Region',
#        'Terminal', 'Boarding_Area', 'Passenger_Count', 'Year', 'Month'],
#       dtype='object')

# %%
sns.distplot(cleaned_df['Passenger_Count'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24704\3822186631.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cleaned_df['Passenger_Count'])
# <Axes: xlabel='Passenger_Count', ylabel='Density'>

# %%
sns.countplot(data=df,x="GEO_Region",palette="plasma_r")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sns.countplot(data=df,x="GEO_Region",y = "Passenger_count",palette="plasma_r")
#       2 plt.xticks(rotation=45)
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2629, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2627     y = 1 if list(x) else None
#    2628 elif x is not None and y is not None:
# -> 2629     raise TypeError("Cannot pass values for both `x` and `y`.")
#    2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    (...)
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#
# TypeError: Cannot pass values for both `x` and `y`.
